# %%
# %reload_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import read_player_stats
import training_data
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import grid_search
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 1000

# %%
#read in rb data for all seasons
total_df = training_data.make_total_data(seasons=range(2004,2015), pages=[0,1,2,3])
#training samples
train_df = training_data.make_training_df(total_df, seasons=range(2004,2013), ppg=True)

# %%
#train on points per game
X_train = np.array(train_df.drop(['Name','FFPPG'], axis=1))
y_train = np.array(train_df['FFPPG'])

#rf model
#model = RandomForestRegressor(n_estimators=500)
#model.fit(X_train, y_train)

#linear regression
parameters = {'alpha': np.logspace(-10,10,num=20)}
model = grid_search.GridSearchCV(linear_model.Ridge(), parameters, cv=10)
model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, solver='auto', tol=0.001),
#        fit_params={}, iid=True, loss_func=None, n_jobs=1,
#        param_grid={'alpha': array([  1.00000e-10,   1.12884e-09,   1.27427e-08,   1.43845e-07,
#          1.62378e-06,   1.83298e-05,   2.06914e-04,   2.33572e-03,
#          2.63665e-02,   2.97635e-01,   3.35982e+00,   3.79269e+01,
#          4.28133e+02,   4.83293e+03,   5.45559e+04,   6.15848e+05,
#          6.95193e+06,   7.84760e+07,   8.85867e+08,   1.00000e+10])},
#        pre_dispatch='2*n_jobs', refit=True, score_func=None, scoring=None,
#        verbose=0)

# %%
model = model.best_estimator_

# %%
eval_df = training_data.make_training_df(total_df, seasons=range(2012,2015), ppg=True)
X_eval = np.array(eval_df.drop(['Name','FFPPG'], axis=1))

y_eval = model.predict(X_eval) #predict 2014 stats

# %%
#compare
pred_summary = eval_df[['Name']]
pred_summary['Predicted'] = y_eval
actual = total_df[total_df.Season == 2014]
actual = actual[['Name','FFPPG']]
pred_summary = pd.merge(pred_summary, actual, on='Name', how='inner')
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
pred_summary
# Out:
#                 Name  Predicted  FFPPG
# 0     AdrianPeterson  13.108092    9.3
# 1      AhmadBradshaw   9.314957   12.1
# 2       AlfonsoSmith   2.572499    1.0
# 3       AlfredMorris  11.164801   10.7
# 4       AnthonyDixon   2.346770    4.6
# 5     AnthonySherman   2.273389    1.3
# 6        AntoneSmith   4.917568    6.7
# 7        ArianFoster   8.784469   18.1
# 8            BenTate   6.206578    6.1
# 9      BernardPierce   4.015243    3.8
# 10       BilalPowell   6.098618    2.1
# 11     BrandonBolden   5.097414    1.7
# 12      BrianLeonard   2.763340    1.5
# 13       BruceMiller   2.542451    2.3
# 14        BryceBrown   3.985012    4.3
# 15         CJSpiller  10.222117    5.4
# 16     CedricPeerman   2.556985    1.2
# 17        ChrisIvory   6.304181    8.5
# 18      ChrisJohnson   9.965714    5.8
# 19    ChrisOgbonnaya   3.644968    3.5
# 20         CyrusGray   1.958608    3.0
# 21         DanHerron   3.746510    5.3
# 22      DanielThomas   4.732662    3.4
# 23     DannyWoodhead   7.619648    2.4
# 24       DarrelYoung   2.980757    3.4
# 25    DarrenMcFadden   5.847733    5.4
# 26     DarrenSproles   6.446789    7.2
# 27  DeAngeloWilliams   8.700216    4.4
# 28     DeMarcoMurray  11.752397   19.0
# 29   DexterMcCluster   4.048017    3.0
# ..               ...        ...    ...
# 51       LamarMiller   5.733418   12.0
# 52       LanceDunbar   3.314171    2.3
# 53  LeGarretteBlount   6.153845    6.0
# 54       LeSeanMcCoy  14.246562   11.1
# 55    LeonWashington   1.532426    3.1
# 56       MarcelReece   5.095938    2.7
# 57        MarkIngram   4.941796   12.7
# 58     MarshawnLynch  12.574186   16.8
# 59        MattAsiata   9.437639    9.9
# 60         MattForte  13.239434   15.3
# 61  MauriceJonesDrew   7.374046    1.5
# 62       MikeTolbert   5.104797    2.1
# 63      PeytonHillis   4.802397    3.4
# 64      PierreThomas   7.579934    7.1
# 65    RashadJennings   7.370784   10.0
# 66        ReggieBush  10.862235    6.1
# 67      RobertTurbin   3.355250    3.9
# 68       RonnieBrown   3.550555    1.3
# 69     RonnieHillman   4.232452   10.2
# 70           RoyHelu   4.089429    6.7
# 71       RyanMathews   9.769026    9.7
# 72       ShaneVereen   7.452847    7.1
# 73      ShaunDraughn   1.935000    1.9
# 74       ShonnGreene   5.621278    4.0
# 75      StevanRidley   8.445760    8.0
# 76     StevenJackson   7.673574    8.1
# 77       TobyGerhart   4.215732    4.5
# 78     TravarisCadet   2.875872    3.0
# 79   TrentRichardson   6.612898    6.2
# 80       WillJohnson   1.708415    0.5
#
# [81 rows x 3 columns]

# %%
pred_summary['Error'] =  pred_summary['FFPPG'] - pred_summary['Predicted']

# %%
ordered_pred = pred_summary.sort(columns='Error', ascending=False)
ordered_pred.set_index('Name', inplace=True)

# %%
top10 = ordered_pred[:10]
bottom10 = ordered_pred[-10:]

# %%
bottom10
# Out:
#                   Predicted  FFPPG     Error
# Name
# BrandonBolden      5.097414    1.7 -3.397414
# AdrianPeterson    13.108092    9.3 -3.808092
# KnowshonMoreno    11.145431    7.2 -3.945431
# BilalPowell        6.098618    2.1 -3.998618
# ChrisJohnson       9.965714    5.8 -4.165714
# DeAngeloWilliams   8.700216    4.4 -4.300216
# ReggieBush        10.862235    6.1 -4.762235
# CJSpiller         10.222117    5.4 -4.822117
# DannyWoodhead      7.619648    2.4 -5.219648
# MauriceJonesDrew   7.374046    1.5 -5.874046

# %%
fig = plt.figure(figsize=(25,9))
p1 = fig.add_subplot(1,2,1)
p1.tick_params(axis='x', labelsize=15)
top10['Error'].plot(kind='bar', alpha=.7)
plt.xlabel('Player', fontsize=20)
p2 = fig.add_subplot(1,2,2)
p2.tick_params(axis='x', labelsize=15)
bottom10['Error'].plot(kind='bar', color='r', alpha=.7)
plt.xlabel('Player', fontsize=20)

# %%
#make 2015 projections
total_train = training_data.make_training_df(total_df, seasons=range(2004,2014), ppg=True)
most_rec_df = training_data.merge_seasons(total_df[total_df.Season == 2013], total_df[total_df.Season == 2014])

# %%
most_rec_df.dropna(inplace=True)

# %%
X_proj = np.array(most_rec_df.drop('Name', axis=1))

# %%
y_proj = model.predict(X_proj)

# %%
most_rec_df['2015 Projection'] = y_proj

# %%
#The projections
most_rec_df[['Name', '2015 Projection']].sort(columns='2015 Projection', ascending=False)
# Out:
#                  Name  2015 Projection
# 47      DeMarcoMurray        15.837534
# 99         LeVeonBell        15.165722
# 103     MarshawnLynch        12.909430
# 105         MattForte        12.669278
# 98        LeSeanMcCoy        12.338365
# 10        ArianFoster        12.060897
# 70      JamaalCharles        11.893649
# 54          EddieLacy        11.851256
# 78         JoiqueBell         9.935301
# 94        LamarMiller         9.551102
# 4        AlfredMorris         9.535696
# 85      JustinForsett         9.484143
# 60          FrankGore         9.128240
# 102        MarkIngram         9.028103
# 63     GiovaniBernard         8.988608
# 6      AndreEllington         8.906944
# 25         CJAnderson         8.571337
# 120    RashadJennings         8.515031
# 129       RyanMathews         8.209882
# 62        FredJackson         8.127793
# 1       AhmadBradshaw         7.867675
# 0      AdrianPeterson         7.744739
# 90     KnowshonMoreno         7.559912
# 81    JonathanStewart         7.450345
# 104        MattAsiata         7.206909
# 28         ChrisIvory         7.014318
# 124        ReggieBush         6.949886
# 127     RonnieHillman         6.919608
# 43      DarrenSproles         6.665579
# 136      StevanRidley         6.593058
# ..                ...              ...
# 139       TheoRiddick         2.961152
# 143     TravarisCadet         2.826279
# 33   ChristineMichael         2.825660
# 20      BrandonBolden         2.821732
# 23        BruceMiller         2.799385
# 35          CyrusGray         2.765525
# 41        DarrelYoung         2.694761
# 113       MikeTolbert         2.681451
# 55         EdwinBaker         2.629486
# 108        MichaelCox         2.535151
# 100    LeonWashington         2.528507
# 68       JackieBattle         2.421692
# 22       BrianLeonard         2.341695
# 131      ShaunDraughn         2.296429
# 126       RonnieBrown         2.248697
# 91       KyleJuszczyk         2.183537
# 75         JohnConner         2.130004
# 76           JohnKuhn         2.122405
# 112         MikeJames         2.082314
# 3        AlfonsoSmith         2.048769
# 27      CedricPeerman         2.020385
# 61       FrankSummers         1.939742
# 8      AnthonySherman         1.911537
# 73         JedCollins         1.654314
# 74       JeromeFelton         1.621997
# 92     LaMichaelJames         1.603523
# 56          ErikLorig         1.559245
# 65       HenryHynoski         1.527974
# 145       TylerClutts         1.492740
# 148       WillJohnson         1.266198
#
# [107 rows x 2 columns]
