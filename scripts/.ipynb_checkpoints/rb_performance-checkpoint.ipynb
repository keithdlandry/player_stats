# %%
# %reload_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import read_player_stats
import training_data
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
from sklearn import cross_validation
from sklearn import grid_search
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 1000

# %%
#read in rb data for all seasons
total_df = training_data.make_total_data(seasons=range(2004,2015), pages=[0,1,2,3])
#training samples
train_df = training_data.make_training_df(total_df, seasons=range(2004,2013), ppg=True)

# %%
#train on points per game
X_train = np.array(train_df.drop(['Name','FFPPG'], axis=1))
y_train = np.array(train_df['FFPPG'])

#rf model
#model = RandomForestRegressor(n_estimators=500)
#model.fit(X_train, y_train)

#linear regression
parameters = {'alpha': np.logspace(-10,10,num=20)}
model = grid_search.GridSearchCV(linear_model.Ridge(), parameters, cv=10)
model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, solver='auto', tol=0.001),
#        fit_params={}, iid=True, loss_func=None, n_jobs=1,
#        param_grid={'alpha': array([  1.00000e-10,   1.12884e-09,   1.27427e-08,   1.43845e-07,
#          1.62378e-06,   1.83298e-05,   2.06914e-04,   2.33572e-03,
#          2.63665e-02,   2.97635e-01,   3.35982e+00,   3.79269e+01,
#          4.28133e+02,   4.83293e+03,   5.45559e+04,   6.15848e+05,
#          6.95193e+06,   7.84760e+07,   8.85867e+08,   1.00000e+10])},
#        pre_dispatch='2*n_jobs', refit=True, score_func=None, scoring=None,
#        verbose=0)

# %%
model = model.best_estimator_

# %%
eval_df = training_data.make_training_df(total_df, seasons=range(2012,2015), ppg=True)
X_eval = np.array(eval_df.drop(['Name','FFPPG'], axis=1))

y_eval = model.predict(X_eval) #predict 2014 stats

# %%
#compare
pred_summary = eval_df[['Name']]
pred_summary['Predicted'] = y_eval
actual = total_df[total_df.Season == 2014]
actual = actual[['Name','FFPPG']]
pred_summary = pd.merge(pred_summary, actual, on='Name', how='inner')
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
pred_summary
# Out:
#                 Name  Predicted  FFPPG
# 0     AdrianPeterson  13.494774    9.3
# 1      AhmadBradshaw   6.730249   12.1
# 2       AlfonsoSmith   2.786275    1.0
# 3       AlfredMorris  11.526553   10.7
# 4       AnthonyDixon   2.516996    4.6
# 5     AnthonySherman   2.569933    1.3
# 6        AntoneSmith   3.743144    6.7
# 7        ArianFoster   7.499178   18.1
# 8            BenTate   5.879449    6.1
# 9      BernardPierce   4.473344    3.8
# 10       BilalPowell   6.118889    2.1
# 11     BrandonBolden   4.588756    1.7
# 12      BrianLeonard   2.745294    1.5
# 13       BruceMiller   2.719378    2.3
# 14        BryceBrown   4.179405    4.3
# 15         CJSpiller  10.819941    5.4
# 16     CedricPeerman   3.238436    1.2
# 17        ChrisIvory   6.376623    8.5
# 18      ChrisJohnson  10.885634    5.8
# 19    ChrisOgbonnaya   3.864286    3.5
# 20         CyrusGray   2.428552    3.0
# 21         DanHerron   3.262473    5.3
# 22      DanielThomas   4.931283    3.4
# 23     DannyWoodhead   8.434893    2.4
# 24       DarrelYoung   3.354593    3.4
# 25    DarrenMcFadden   5.303040    5.4
# 26     DarrenSproles   7.323784    7.2
# 27  DeAngeloWilliams   9.262276    4.4
# 28     DeMarcoMurray  10.900541   19.0
# 29   DexterMcCluster   4.503833    3.0
# ..               ...        ...    ...
# 51       LamarMiller   5.927795   12.0
# 52       LanceDunbar   3.262317    2.3
# 53  LeGarretteBlount   6.232349    6.0
# 54       LeSeanMcCoy  14.846912   11.1
# 55    LeonWashington   2.294482    3.1
# 56       MarcelReece   5.825941    2.7
# 57        MarkIngram   4.684425   12.7
# 58     MarshawnLynch  13.442841   16.8
# 59        MattAsiata   4.480856    9.9
# 60         MattForte  13.650442   15.3
# 61  MauriceJonesDrew   7.548141    1.5
# 62       MikeTolbert   5.174123    2.1
# 63      PeytonHillis   4.051745    3.4
# 64      PierreThomas   7.865846    7.1
# 65    RashadJennings   7.098804   10.0
# 66        ReggieBush  11.104875    6.1
# 67      RobertTurbin   3.790821    3.9
# 68       RonnieBrown   3.839937    1.3
# 69     RonnieHillman   4.022801   10.2
# 70           RoyHelu   4.243278    6.7
# 71       RyanMathews  10.017874    9.7
# 72       ShaneVereen   6.253293    7.1
# 73      ShaunDraughn   2.694920    1.9
# 74       ShonnGreene   5.459079    4.0
# 75      StevanRidley   8.246919    8.0
# 76     StevenJackson   7.502557    8.1
# 77       TobyGerhart   3.948507    4.5
# 78     TravarisCadet   2.795112    3.0
# 79   TrentRichardson   7.055761    6.2
# 80       WillJohnson   2.154269    0.5
#
# [81 rows x 3 columns]

# %%
pred_summary['Error'] =  pred_summary['FFPPG'] - pred_summary['Predicted']

# %%
ordered_pred = pred_summary.sort(columns='Error', ascending=False)
ordered_pred.set_index('Name', inplace=True)

# %%
top10 = ordered_pred[:10]
bottom10 = ordered_pred[-10:]

# %%
bottom10
# Out:
#                   Predicted  FFPPG     Error
# Name
# LeSeanMcCoy       14.846912   11.1 -3.746912
# BilalPowell        6.118889    2.1 -4.018889
# KnowshonMoreno    11.305256    7.2 -4.105256
# AdrianPeterson    13.494774    9.3 -4.194774
# DeAngeloWilliams   9.262276    4.4 -4.862276
# ReggieBush        11.104875    6.1 -5.004875
# ChrisJohnson      10.885634    5.8 -5.085634
# CJSpiller         10.819941    5.4 -5.419941
# DannyWoodhead      8.434893    2.4 -6.034893
# MauriceJonesDrew   7.548141    1.5 -6.048141

# %%
fig = plt.figure(figsize=(25,9))
p1 = fig.add_subplot(1,2,1)
p1.tick_params(axis='x', labelsize=15)
top10['Error'].plot(kind='bar', alpha=.7)
plt.xlabel('Player', fontsize=20)
p2 = fig.add_subplot(1,2,2)
p2.tick_params(axis='x', labelsize=15)
bottom10['Error'].plot(kind='bar', color='r', alpha=.7)
plt.xlabel('Player', fontsize=20)

# %%
#make 2015 projections
total_train = training_data.make_training_df(total_df, seasons=range(2004,2014), ppg=True)
most_rec_df = training_data.merge_seasons(total_df[total_df.Season == 2013], total_df[total_df.Season == 2014])

# %%
most_rec_df.dropna(inplace=True)

# %%
X_proj = np.array(most_rec_df.drop('Name', axis=1))

# %%
y_proj = model.predict(X_proj)

# %%
most_rec_df['2015 Projection'] = y_proj

# %%
#The projections
most_rec_df[['Name', '2015 Projection']].sort(columns='2015 Projection', ascending=False)
# Out:
#                  Name  2015 Projection
# 47      DeMarcoMurray        15.778341
# 99         LeVeonBell        15.173803
# 103     MarshawnLynch        13.765294
# 105         MattForte        13.637217
# 98        LeSeanMcCoy        13.318867
# 70      JamaalCharles        13.153362
# 54          EddieLacy        12.362670
# 10        ArianFoster        11.677372
# 78         JoiqueBell        10.159459
# 4        AlfredMorris        10.124576
# 94        LamarMiller         9.623644
# 60          FrankGore         9.530878
# 63     GiovaniBernard         9.208657
# 85      JustinForsett         9.158076
# 6      AndreEllington         8.880534
# 25         CJAnderson         8.401627
# 102        MarkIngram         8.349327
# 62        FredJackson         8.014614
# 120    RashadJennings         7.806166
# 28         ChrisIvory         7.508566
# 29       ChrisJohnson         7.328804
# 81    JonathanStewart         7.105002
# 124        ReggieBush         7.094424
# 129       RyanMathews         6.954025
# 43      DarrenSproles         6.922507
# 130       ShaneVereen         6.823109
# 1       AhmadBradshaw         6.808600
# 90     KnowshonMoreno         6.691113
# 104        MattAsiata         6.611675
# 137     StevenJackson         6.462041
# ..                ...              ...
# 23        BruceMiller         3.179481
# 55         EdwinBaker         3.140236
# 33   ChristineMichael         3.100389
# 20      BrandonBolden         3.068598
# 143     TravarisCadet         3.029663
# 113       MikeTolbert         3.010478
# 41        DarrelYoung         2.917880
# 100    LeonWashington         2.884939
# 112         MikeJames         2.772353
# 141      TommyBohanon         2.735248
# 108        MichaelCox         2.710622
# 131      ShaunDraughn         2.693988
# 68       JackieBattle         2.670597
# 35          CyrusGray         2.664202
# 22       BrianLeonard         2.652576
# 91       KyleJuszczyk         2.630588
# 126       RonnieBrown         2.584249
# 75         JohnConner         2.546516
# 27      CedricPeerman         2.537505
# 3        AlfonsoSmith         2.478364
# 145       TylerClutts         2.458802
# 92     LaMichaelJames         2.387909
# 61       FrankSummers         2.378035
# 8      AnthonySherman         2.367198
# 65       HenryHynoski         2.309895
# 76           JohnKuhn         2.280414
# 74       JeromeFelton         2.271135
# 56          ErikLorig         1.917781
# 73         JedCollins         1.909391
# 148       WillJohnson         1.805768
#
# [107 rows x 2 columns]
