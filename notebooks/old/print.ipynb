# %% [markdown]
# #TE

# %%
te_table
# Out:
#                 Name  2015 Projection  Value Above Baseline  Group  Bye  MFL  \
# 0        JimmyGraham        15.046483              6.460160      0    9   32
# 1      RobGronkowski        14.061922              5.475598      0    4    6
# 2          GregOlsen        12.514160              3.927837      0    5   61
# 3   MartellusBennett        11.457613              2.871289      0    7   77
# 4       JuliusThomas        11.352958              2.766635      0    8   88
# 5       AntonioGates        11.294143              2.707819      0   10  132
# 6      DelanieWalker        11.087186              2.500863      0    4  119
# 7        JasonWitten        10.488086              1.901763      0    6  118
# 8        CobyFleener         9.702871              1.116548      0   10  162
# 9        CharlesClay         9.281677              0.695353      0    8  176
# 10       HeathMiller         8.924242              0.337919      0   11  171
# ...
