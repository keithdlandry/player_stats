# %% [markdown]
# #Draft Sheet

# %%
# %reload_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 250

# %%
#tables
qb_table = pd.read_csv('../projections/qb_summary_table.csv', index_col=0)
rb_table = pd.read_csv('../projections/rb_summary_table.csv', index_col=0)
wr_table = pd.read_csv('../projections/wr_summary_table.csv', index_col=0)
te_table = pd.read_csv('../projections/te_summary_table.csv', index_col=0)

# %% [markdown]
# #QB

# %%
qb_table
# Out:
#                  Name  2015 Projection  Value Above Baseline  Group  Bye  MFL  \
# 0       PeytonManning        25.857974              6.057504      2    7   68
# 1           DrewBrees        24.217709              4.417239      2   11   79
# 2          AndrewLuck        23.341387              3.540917      2   10   21
# 3   BenRoethlisberger        21.330288              1.529819      2   11   78
# 4        AaronRodgers        21.320408              1.519938      2    7   28
# 5        PhilipRivers        21.269777              1.469307      2   10  121
# 6            MattRyan        20.611727              0.811257      2   10   91
# 7       RussellWilson        20.266972              0.466502      2    9   58
# 8            TonyRomo        20.255000              0.454530      2    6  103
# 9            TomBrady        20.210638              0.410168      2    4  107
# 10    MatthewStafford        20.022377              0.221907      2    9  111
# ...

# %% [markdown]
# #RB

# %%
rb_table
# Out:
#                 Name  2015 Projection  Value Above Baseline  Group  Bye  MFL  \
# 0         LeVeonBell        19.013159             10.268550      1   11    1
# 1      DeMarcoMurray        18.713261              9.968651      1    8   14
# 2          MattForte        17.427415              8.682806      1    7   13
# 3      MarshawnLynch        15.431197              6.686588      1    9    7
# 4      JamaalCharles        15.013924              6.269315      1    9    3
# 5        ArianFoster        14.540925              5.796316      1    9   34
# 6        LeSeanMcCoy        14.436467              5.691858      1    8   17
# 7          EddieLacy        14.340386              5.595777      1    7    4
# 8         JoiqueBell        12.373312              3.628703      1    9   65
# 9     GiovaniBernard        11.911546              3.166937      1    7   54
# 10    AndreEllington        11.808672              3.064062      1    9   39
# ...

# %% [markdown]
# #WR

# %%
wr_table
# Out:
#                     Name  2015 Projection  Value Above Baseline  Group  Bye  \
# 0           AntonioBrown        19.570178             10.394666      0   11
# 1        DemaryiusThomas        18.163368              8.987856      0    7
# 2              DezBryant        17.307398              8.131886      0    6
# 3          AlshonJeffery        15.762167              6.586655      0    7
# 4            RandallCobb        15.729187              6.553675      0    7
# 5             JulioJones        15.438448              6.262936      0   10
# 6        EmmanuelSanders        15.199328              6.023816      0    7
# 7          CalvinJohnson        14.987153              5.811641      0    9
# 8                AJGreen        14.445573              5.270061      0    7
# 9               TYHilton        14.225956              5.050444      0   10
# 10         JulianEdelman        13.792098              4.616586      0    4
# ...

# %% [markdown]
# #TE

# %%
te_table
# Out:
#                 Name  2015 Projection  Value Above Baseline  Group  Bye  MFL  \
# 0        JimmyGraham        15.046483              6.460160      0    9   32
# 1      RobGronkowski        14.061922              5.475598      0    4    6
# 2          GregOlsen        12.514160              3.927837      0    5   61
# 3   MartellusBennett        11.457613              2.871289      0    7   77
# 4       JuliusThomas        11.352958              2.766635      0    8   88
# 5       AntonioGates        11.294143              2.707819      0   10  132
# 6      DelanieWalker        11.087186              2.500863      0    4  119
# 7        JasonWitten        10.488086              1.901763      0    6  118
# 8        CobyFleener         9.702871              1.116548      0   10  162
# 9        CharlesClay         9.281677              0.695353      0    8  176
# 10       HeathMiller         8.924242              0.337919      0   11  171
# ...
