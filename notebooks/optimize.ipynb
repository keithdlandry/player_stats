# %%
# %reload_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 250
sys.path.append('../')
import read_player_stats
import training_data
import game_by_game

# %%
positions = ['QB', 'RB', 'WR', 'TE']
projs = [pd.read_csv('../projections/weekly/2015_w2/' + pos + '_proj_and_sal.csv', index_col=0) for pos in positions]

# %%
projs = [pos[pos.DPP < 800] for pos in projs]
pt_thresh = [13, 7, 7, 7]
projs = [pos[pos.Projection > thresh] for thresh, pos in zip(pt_thresh, projs)]

# %%
projs[0]
# Out:
#                  Name  Projection  Salary Position         DPP
# 0        AaronRodgers     19.2645    9300       QB  482.753251
# 1            MattRyan     17.6955    8700       QB  491.650420
# 2           NickFoles     17.6690    6500       QB  367.875941
# 3   BenRoethlisberger     17.6260    8400       QB  476.568705
# 4           DrewBrees     17.1085    8900       QB  520.209253
# 5       RussellWilson     16.8855    8500       QB  503.390483
# 6       RyanTannehill     16.6515    8000       QB  480.437198
# 7          EliManning     16.0610    8000       QB  498.100990
# 8            TonyRomo     15.9875    8500       QB  531.665364
# 9            TomBrady     15.8255    8300       QB  524.470001
# 10       PhilipRivers     15.5210    8200       QB  528.316474
# 11       CarsonPalmer     15.4200    7800       QB  505.836576
# 12          CamNewton     15.3950    7700       QB  500.162390
# 13    ColinKaepernick     15.3840    7800       QB  507.020281
# ...

# %%
for entry in projs:
    print(entry)
# Out:
#                  Name  Projection  Salary Position         DPP
# 0        AaronRodgers     19.2645    9300       QB  482.753251
# 1            MattRyan     17.6955    8700       QB  491.650420
# 2           NickFoles     17.6690    6500       QB  367.875941
# 3   BenRoethlisberger     17.6260    8400       QB  476.568705
# 4           DrewBrees     17.1085    8900       QB  520.209253
# 5       RussellWilson     16.8855    8500       QB  503.390483
# 6       RyanTannehill     16.6515    8000       QB  480.437198
# 7          EliManning     16.0610    8000       QB  498.100990
# 8            TonyRomo     15.9875    8500       QB  531.665364
# 9            TomBrady     15.8255    8300       QB  524.470001
# 10       PhilipRivers     15.5210    8200       QB  528.316474
# 11       CarsonPalmer     15.4200    7800       QB  505.836576
# 12          CamNewton     15.3950    7700       QB  500.162390
# 13    ColinKaepernick     15.3840    7800       QB  507.020281
# ...
